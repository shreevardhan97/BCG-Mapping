# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
#read csv
df = pd.read_csv('./Sangrur/result.csv')
df.head()
#show all columns
pd.set_option('display.max_columns', None)
df.head()
#show features
df2 = df[['features__attributes__objectid', 'features__attributes__schcd',
       'features__attributes__schname', 'features__attributes__schcat',
       'features__attributes__school_cat', 'features__attributes__schtype',
       'features__attributes__school_typ', 'features__attributes__schmgt',
       'features__attributes__management', 'features__attributes__rururb',
       'features__attributes__location', 'features__attributes__pincode',
       'features__attributes__dtname', 'features__attributes__udise_stco',
       'features__attributes__stname', 'features__attributes__vilname',
       'features__attributes__longitude', 'features__attributes__latitude',
       'features__attributes__stcode11', 'features__attributes__dtcode11',
       'features__attributes__sdtcode11', 'features__attributes__sdtname',
       'features__geometry__x', 'features__geometry__y']]
# Out:
# Index(['displayFieldName', 'transform__originPosition', 'transform__scale',
#        'transform__translate', 'fieldAliases__objectid', 'fieldAliases__schcd',
#        'fieldAliases__schname', 'fieldAliases__schcat',
#        'fieldAliases__school_cat', 'fieldAliases__schtype',
#        'fieldAliases__school_typ', 'fieldAliases__schmgt',
#        'fieldAliases__management', 'fieldAliases__rururb',
#        'fieldAliases__location', 'fieldAliases__pincode',
#        'fieldAliases__dtname', 'fieldAliases__udise_stco',
#        'fieldAliases__stname', 'fieldAliases__vilname',
#        'fieldAliases__longitude', 'fieldAliases__latitude',
#        'fieldAliases__stcode11', 'fieldAliases__dtcode11',
#        'fieldAliases__sdtcode11', 'fieldAliases__sdtname', 'geometryType',
#        'spatialReference__wkid', 'spatialReference__latestWkid',
#        'fields__name', 'fields__type', 'fields__alias', 'fields__length',
#        'features__attributes__objectid', 'features__attributes__schcd',
#        'features__attributes__schname', 'features__attributes__schcat',
#        'features__attributes__school_cat', 'features__attributes__schtype',
#        'features__attributes__school_typ', 'features__attributes__schmgt',
#        'features__attributes__management', 'features__attributes__rururb',
#        'features__attributes__location', 'features__attributes__pincode',
#        'features__attributes__dtname', 'features__attributes__udise_stco',
#        'features__attributes__stname', 'features__attributes__vilname',
#        'features__attributes__longitude', 'features__attributes__latitude',
#        'features__attributes__stcode11', 'features__attributes__dtcode11',
#        'features__attributes__sdtcode11', 'features__attributes__sdtname',
#        'features__geometry__x', 'features__geometry__y'],
#       dtype='object')

# %%
# filter out district with name sangrur
df2 = df2[df2['features__attributes__dtname'] == 'Sangrur']
df2['LAT'] = df2['features__attributes__latitude']
df2['LON'] = df2['features__attributes__longitude']
df2
# Out:
#      features__attributes__objectid  features__attributes__schcd  \
# 0                           1415315                   3161104201
# 1                           1416734                   3161103601
# 2                           1416738                   3161103602
# 3                           1418651                   3160100704
# 4                           1419281                   3160101002
# ..                              ...                          ...
# 573                         1418405                   3160712002
# 574                         1418985                   3160712901
# 579                         1417486                   3160703102
# 580                         1417977                   3160712502
# 581                         1418153                   3160712503
#
#     features__attributes__schname  features__attributes__schcat  \
# 0            GPS RAM NAGAR CHANNA                             1
# 1                     GPS BADESHA                             1
# 2                     GMS BADESHA                             4
# 3      KAPIL MODEL SEN SEC SCHOOL                             3
# 4                    GHS PHARWALI                             7
# ..                            ...                           ...
# 573                    GHS SAROUD                             7
# 574                    GPS CHUPKA                             1
# 579                   GSSS HATHOA                             5
# 580                GMS BADSHAHPUR                             4
# 581          ENGLISH MODEL SCHOOL                             2
#
#     features__attributes__school_cat  features__attributes__schtype  \
# 0                            Primary                              3
# 1                            Primary                              3
# 2                 Upper Primary Only                              3
# 3            Higher Secondary (1-12)                              3
# 4                   Secondary (6-10)                              3
# ..                               ...                            ...
# 573                 Secondary (6-10)                              3
# 574                          Primary                              3
# 579         Higher Secondary  (6-12)                              3
# 580               Upper Primary Only                              3
# 581                    Upper Primary                              3
#
#     features__attributes__school_typ  features__attributes__schmgt  \
# 0                              Co-Ed                             1
# 1                              Co-Ed                             1
# 2                              Co-Ed                             1
# 3                              Co-Ed                             5
# 4                              Co-Ed                             1
# ..                               ...                           ...
# 573                            Co-Ed                             1
# 574                            Co-Ed                             1
# 579                            Co-Ed                             1
# 580                            Co-Ed                             1
# 581                            Co-Ed                             5
#
#     features__attributes__management  features__attributes__rururb  \
# 0            Department of Education                             1
# 1            Department of Education                             1
# 2            Department of Education                             1
# 3       Private Unaided (recognized)                             1
# 4            Department of Education                             1
# ..                               ...                           ...
# 573          Department of Education                             1
# 574          Department of Education                             1
# 579          Department of Education                             1
# 580          Department of Education                             1
# 581     Private Unaided (recognized)                             1
#
#     features__attributes__location  features__attributes__pincode  \
# 0                                                          148025
# 1                                                          148020
# 2                                                          148020
# 3                                                          148020
# 4                                                          148020
# ..                             ...                            ...
# 573                                                        148023
# 574                                                        148023
# 579                                                        148023
# 580                                                        148023
# 581                                                        148023
#
#     features__attributes__dtname  features__attributes__udise_stco  \
# 0                        Sangrur                                 3
# 1                        Sangrur                                 3
# 2                        Sangrur                                 3
# 3                        Sangrur                                 3
# 4                        Sangrur                                 3
# ..                           ...                               ...
# 573                      Sangrur                                 3
# 574                      Sangrur                                 3
# 579                      Sangrur                                 3
# 580                      Sangrur                                 3
# 581                      Sangrur                                 3
#
#     features__attributes__stname features__attributes__vilname  \
# 0                         PUNJAB
# 1                         PUNJAB
# 2                         PUNJAB
# 3                         PUNJAB
# 4                         PUNJAB
# ..                           ...                           ...
# 573                       PUNJAB
# 574                       PUNJAB
# 579                       PUNJAB
# 580                       PUNJAB
# 581                       PUNJAB
#
#      features__attributes__longitude  features__attributes__latitude  \
# 0                          75.729200                       30.460960
# 1                          75.730656                       30.503814
# 2                          75.730960                       30.503888
# 3                          75.736983                       30.571057
# 4                          75.734588                       30.592923
# ..                               ...                             ...
# 573                        75.922419                       30.561333
# 574                        75.919694                       30.582934
# 579                        75.907320                       30.528690
# 580                        75.909031                       30.546580
# 581                        75.909343                       30.554025
#
#      features__attributes__stcode11  features__attributes__dtcode11  \
# 0                                 3                              53
# 1                                 3                              53
# 2                                 3                              53
# 3                                 3                              53
# 4                                 3                              53
# ..                              ...                             ...
# 573                               3                              53
# 574                               3                              53
# 579                               3                              53
# 580                               3                              53
# 581                               3                              53
#
#      features__attributes__sdtcode11 features__attributes__sdtname  \
# 0                                270                         Dhuri
# 1                                270                         Dhuri
# 2                                270                         Dhuri
# 3                                269                    Malerkotla
# 4                                269                    Malerkotla
# ..                               ...                           ...
# 573                              269                    Malerkotla
# 574                              269                    Malerkotla
# 579                              269                    Malerkotla
# 580                              269                    Malerkotla
# 581                              269                    Malerkotla
#
#      features__geometry__x  features__geometry__y        LAT        LON
# 0                   110288                 -46612  30.460960  75.729200
# 1                   110290                 -46685  30.503814  75.730656
# 2                   110290                 -46685  30.503888  75.730960
# 3                   110299                 -46798  30.571057  75.736983
# 4                   110296                 -46835  30.592923  75.734588
# ..                     ...                    ...        ...        ...
# 573                 110569                 -46782  30.561333  75.922419
# 574                 110565                 -46819  30.582934  75.919694
# 579                 110547                 -46727  30.528690  75.907320
# 580                 110550                 -46757  30.546580  75.909031
# 581                 110550                 -46770  30.554025  75.909343
#
# [315 rows x 26 columns]

# %%
def filter_district(df, district):
    df = df[df['features__attributes__dtname'] == district]
    df['LAT'] = df['features__attributes__latitude']
    df['LON'] = df['features__attributes__longitude']
    return df

# %%
# #use streamlit to show data
# st.title('Schools in Sangrur')
# st.write(df2)
# #show map of sangrur
# st.map(df2)
# map_type = st.selectbox('Select map type', ['stamen', 'carto', 'openstreetmap', 'esri', 'stamenterrain', 'stamentoner', 'stamenwatercolor', 'stamenterrain'])
# st.map(df2[['LAT', 'LON']], zoom=10, use_container_width=True, height=500, tooltip=df2['features__attributes__schname'], map_type=map_type)
# #show map of sangrur with markers and zoom

st.title('BCG School Mapping')
#show other details of the school when clicked on marker
#use folium to show map
import folium
from streamlit_folium import folium_static
#put bcg logo on top of the site

#create a dropdown to select district
district = st.selectbox('Select District', df2['features__attributes__dtname'].unique())
df2 = filter_district(df, district)

m = folium.Map(location=[df2['LAT'].mean(), df2['LON'].mean()], zoom_start=10)
for i in range(0,len(df2)):
    mypopup = "School Name:{} \n Type:{} \n Management:{} \n Location:{} \n Pincode:{}".format(df2.iloc[i]['features__attributes__schname'], df2.iloc[i]['features__attributes__school_typ'], df2.iloc[i]['features__attributes__management'], df2.iloc[i]['features__attributes__sdtname'], df2.iloc[i]['features__attributes__pincode'])
    html = '''
    <h3>School Name:{}</h3>
    <p>Type:{}</p>
    <p>Management:{}</p>
    <p>Location:{}</p>
    <p>Pincode:{}</p>
    '''.format(df2.iloc[i]['features__attributes__schname'], df2.iloc[i]['features__attributes__school_typ'], df2.iloc[i]['features__attributes__management'], df2.iloc[i]['features__attributes__sdtname'], df2.iloc[i]['features__attributes__pincode'])
    iframe = folium.IFrame(html=html, width=200, height=200)
    folium.Marker(
        location=[df2.iloc[i]['LAT'], df2.iloc[i]['LON']],
        popup=folium.Popup(iframe, max_width=200),
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)
folium_static(m)
# Out:
# DeltaGenerator()

# %%
#run streamlit
#streamlit run Mapping.py
